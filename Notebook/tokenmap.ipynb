# %% [markdown]
# ### Load joblib

# %%
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
save_path = "/home/realist/projects/token-heatmap/Database/df_prices.joblib"
df_prices_loaded =joblib.load(save_path)

df_prices_loaded.head()
# Out:
#                            bitcoin     ethereum      solana    ripple
# timestamp
# 2025-07-06 14:00:00  108852.242818  2560.016103  151.526358       NaN
# 2025-07-06 15:00:00  108881.002859  2558.079219  151.513413  2.270192
# 2025-07-06 16:00:00  108842.004636  2555.859603  151.277611  2.275761
# 2025-07-06 17:00:00  108873.266827  2551.561590  152.667671  2.275187
# 2025-07-06 18:00:00  108922.671960  2547.530001  152.489191  2.267808

# %% [markdown]
# ### Token correlation heatmap

# %%
# Calculate the correlation matrix
corr = df_prices_loaded.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Token Volatility

# %%
# Compute volatility (standard deviation of returns) for each token

# Calculate log returns
returns = df_prices_loaded.pct_change().apply(lambda x: np.log1p(x))

# Compute volatility (standard deviation of log returns)
volatility_table = returns.std()

print("Volatility for each token:")
volatility_table
# Out:
# Volatility for each token:
# bitcoin     0.003191
# ethereum    0.006443
# solana      0.006887
# ripple      0.008499
# dtype: float64

# %% [markdown]
# ### Correlation of token return

# %%
returns.head()
# Out:
#                       bitcoin  ethereum    solana    ripple
# timestamp
# 2025-07-06 14:00:00       NaN       NaN       NaN       NaN
# 2025-07-06 15:00:00  0.000264 -0.000757 -0.000085       NaN
# 2025-07-06 16:00:00 -0.000358 -0.000868 -0.001558  0.002450
# 2025-07-06 17:00:00  0.000287 -0.001683  0.009147 -0.000252
# 2025-07-06 18:00:00  0.000454 -0.001581 -0.001170 -0.003249

# %%
# Calculate the correlation matrix
corr = returns.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Token Correlation Heatmap")
plt.show()
